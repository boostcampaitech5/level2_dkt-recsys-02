# %%
pwd
# Out:
# '/opt/ml/input/kys/level2_dkt-recsys-02/code/dkt'

# %%
# !python train.py --device gpu --model BERT
#!python inference.py --device gpu --model BERT
# Out:
# wandb: Currently logged in as: kimyoungseo0330. Use `wandb login --relogin` to force relogin
# 2023-05-10 02:18:50,559 - root - INFO - Preparing data ...
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/wandb/run-20230510_021932-e36ljkto
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run leafy-bush-17
# wandb: ⭐️ View project at https://wandb.ai/kimyoungseo0330/dkt
# wandb: 🚀 View run at https://wandb.ai/kimyoungseo0330/dkt/runs/e36ljkto
# 2023-05-10 02:19:39,605 - root - INFO - Building Model ...
# 2023-05-10 02:19:41,111 - root - INFO - Start Training ...
# 2023-05-10 02:19:41,113 - root - INFO - Start Training: Epoch 1
# 2023-05-10 02:19:41,874 - root - INFO - Training steps: 0 Loss: 0.7094
# 2023-05-10 02:19:42,518 - root - INFO - Training steps: 50 Loss: 0.7093
# 2023-05-10 02:19:42,839 - root - INFO - TRAIN AUC : 0.6459 ACC : 0.6152
# ...

# %%
# !python train.py --device gpu --model BERT
#!python inference.py --device gpu --model BERT
# Out:
# wandb: Currently logged in as: kimyoungseo0330. Use `wandb login --relogin` to force relogin
# 2023-05-12 05:44:15,411 - root - INFO - Preparing data ...
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/wandb/run-20230512_054514-iqjqa3sj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run astral-field-19
# wandb: ⭐️ View project at https://wandb.ai/kimyoungseo0330/dkt
# wandb: 🚀 View run at https://wandb.ai/kimyoungseo0330/dkt/runs/iqjqa3sj
# 2023-05-12 05:45:21,920 - root - INFO - Building Model ...
# 2023-05-12 05:45:23,415 - root - INFO - Start Training ...
# 2023-05-12 05:45:23,416 - root - INFO - Start Training: Epoch 1
# 2023-05-12 05:45:24,176 - root - INFO - Training steps: 0 Loss: 0.7094
# 2023-05-12 05:45:24,862 - root - INFO - Training steps: 50 Loss: 0.7093
# 2023-05-12 05:45:25,196 - root - INFO - TRAIN AUC : 0.6459 ACC : 0.6152
# ...

# %%
# !python train.py --device gpu --model LSTM
# !python inference.py --device cpu --model LSTM
# Out:
# wandb: Currently logged in as: kimyoungseo0330. Use `wandb login --relogin` to force relogin
# 2023-05-10 09:08:27,754 - root - INFO - Preparing data ...
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/wandb/run-20230510_090903-yr2loc6y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run prime-glade-18
# wandb: ⭐️ View project at https://wandb.ai/kimyoungseo0330/dkt
# wandb: 🚀 View run at https://wandb.ai/kimyoungseo0330/dkt/runs/yr2loc6y
# 2023-05-10 09:09:11,126 - root - INFO - Building Model ...
# 2023-05-10 09:09:13,430 - root - INFO - Start Training ...
# 2023-05-10 09:09:13,431 - root - INFO - Start Training: Epoch 1
# 2023-05-10 09:09:13,871 - root - INFO - Training steps: 0 Loss: 0.6959
# 2023-05-10 09:09:14,430 - root - INFO - Training steps: 50 Loss: 0.6897
# 2023-05-10 09:09:14,709 - root - INFO - TRAIN AUC : 0.5272 ACC : 0.5173
# ...

# %%
# !python train.py --device gpu --model LSTMATTN
# Out:
# wandb: Currently logged in as: kimyoungseo0330. Use `wandb login --relogin` to force relogin
# 2023-05-09 19:23:13,403 - root - INFO - Preparing data ...
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/wandb/run-20230509_192351-a33emu7o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stellar-firebrand-9
# wandb: ⭐️ View project at https://wandb.ai/kimyoungseo0330/dkt
# wandb: 🚀 View run at https://wandb.ai/kimyoungseo0330/dkt/runs/a33emu7o
# 2023-05-09 19:23:58,641 - root - INFO - Building Model ...
# 2023-05-09 19:24:00,901 - root - INFO - Start Training ...
# 2023-05-09 19:24:00,902 - root - INFO - Start Training: Epoch 1
# 2023-05-09 19:24:01,347 - root - INFO - Training steps: 0 Loss: 0.7567
# 2023-05-09 19:24:01,902 - root - INFO - Training steps: 50 Loss: 0.6671
# 2023-05-09 19:24:02,181 - root - INFO - TRAIN AUC : 0.5777 ACC : 0.5584
# ...

# %%
# !python train.py --device gpu --model LSTM
# Out:
# 2023-05-09 20:33:30,073 - root - INFO - Preparing data ...
# 2023-05-09 20:34:06,727 - root - INFO - Building Model ...
# 2023-05-09 20:34:09,023 - root - INFO - Start Training ...
# 2023-05-09 20:34:09,024 - root - INFO - Start Training: Epoch 1
# 2023-05-09 20:34:09,448 - root - INFO - Training steps: 0 Loss: 0.6959
# 2023-05-09 20:34:09,996 - root - INFO - Training steps: 50 Loss: 0.6897
# 2023-05-09 20:34:10,268 - root - INFO - TRAIN AUC : 0.5272 ACC : 0.5173
# 2023-05-09 20:34:10,695 - root - INFO - VALID AUC : 0.6823 ACC : 0.5468
# Traceback (most recent call last):
#   File "/opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/train.py", line 38, in <module>
#     main(args)
#   File "/opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/train.py", line 32, in main
#     trainer.run(args=args, train_data=train_data, valid_data=valid_data, model=model)
#   File "/opt/ml/input/kys/level2_dkt-recsys-02/code/dkt/dkt/trainer.py", line 50, in run
#     wandb.log(dict(epoch=epoch,
# ...

# %%
wandb login --relogin
# Out:
#   Cell In[2], line 1
#     wandb login --relogin
#           ^
# SyntaxError: invalid syntax
